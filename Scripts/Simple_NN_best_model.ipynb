# %%
# import dependencies
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def load_split_data(csv_file, normalize=False, standardize=False):
  scale_indicator = []
  model_df = pd.read_csv(csv_file)

  # shuffle the data before splitting
  model_df = model_df.sample(frac=1)

  y = model_df['category'].copy()
  X = model_df.drop('category', axis=1).copy()

  if normalize:
    norm_indicator = "Normalized"
    scale_indicator.append(norm_indicator)
    X = preprocessing.normalize(X)
  elif standardize:
    stand_indicator = "Standardized"
    scale_indicator.append(stand_indicator)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
  else:
    stand_indicator = "Unscaled"
  return X, y, scale_indicator

# %%
def shuffle_feature_and_label():
  features = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Schizophrenia Classification Project/Features/relevant_timeseries_features.csv")
  labels = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Schizophrenia Classification Project/Data/labels.csv")
  features['labels'] = labels
  # shuffle the dataset
  shuffled_df = features.sample(frac=1).reset_index(drop=True)
  return shuffled_df

# %%
model_data = "/content/drive/My Drive/Colab Notebooks/Schizophrenia Classification Project/Data/model_data.csv"
X, y, scale_indicator = load_split_data(model_data, standardize=True)
print(scale_indicator)

# shuffle the data before splitting
# df = shuffle_feature_and_label()
# Out:
# ['Standardized']

# %%
# extract X and y
# X = df.iloc[:, :-1]
# y = df['labels']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

# %%
# Training

inputs = tf.keras.Input(shape=(X_train.shape[1]))
x = tf.keras.layers.Dense(256, activation='relu')(inputs)
x = tf.keras.layers.Dense(256, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc')
    ]
)

batch_size = 32
epochs = 50

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.ReduceLROnPlateau()
    ]
)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 2s 70ms/step - loss: 0.6516 - accuracy: 0.6103 - auc: 0.6651 - val_loss: 0.6269 - val_accuracy: 0.6286 - val_auc: 0.7319 - lr: 0.0010
# Epoch 2/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5212 - accuracy: 0.7574 - auc: 0.8643 - val_loss: 0.6367 - val_accuracy: 0.6286 - val_auc: 0.7373 - lr: 0.0010
# Epoch 3/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4517 - accuracy: 0.8088 - auc: 0.9098 - val_loss: 0.6149 - val_accuracy: 0.6286 - val_auc: 0.7101 - lr: 0.0010
# Epoch 4/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3972 - accuracy: 0.8676 - auc: 0.9289 - val_loss: 0.6060 - val_accuracy: 0.6571 - val_auc: 0.7174 - lr: 0.0010
# Epoch 5/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3494 - accuracy: 0.8750 - auc: 0.9464 - val_loss: 0.6217 - val_accuracy: 0.6857 - val_auc: 0.7446 - lr: 0.0010
# Epoch 6/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3193 - accuracy: 0.8824 - auc: 0.9583 - val_loss: 0.6134 - val_accuracy: 0.6571 - val_auc: 0.7609 - lr: 0.0010
# Epoch 7/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2860 - accuracy: 0.8897 - auc: 0.9686 - val_loss: 0.6293 - val_accuracy: 0.6571 - val_auc: 0.7609 - lr: 0.0010
# Epoch 8/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2578 - accuracy: 0.8897 - auc: 0.9718 - val_loss: 0.6474 - val_accuracy: 0.6857 - val_auc: 0.7754 - lr: 0.0010
# Epoch 9/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2385 - accuracy: 0.9044 - auc: 0.9738 - val_loss: 0.6671 - val_accuracy: 0.6571 - val_auc: 0.7736 - lr: 0.0010
# Epoch 10/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2257 - accuracy: 0.9191 - auc: 0.9753 - val_loss: 0.6544 - val_accuracy: 0.6857 - val_auc: 0.7699 - lr: 0.0010
# Epoch 11/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2072 - accuracy: 0.9265 - auc: 0.9772 - val_loss: 0.6752 - val_accuracy: 0.6857 - val_auc: 0.7790 - lr: 0.0010
# Epoch 12/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1895 - accuracy: 0.9265 - auc: 0.9848 - val_loss: 0.6822 - val_accuracy: 0.7143 - val_auc: 0.7935 - lr: 0.0010
# Epoch 13/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1762 - accuracy: 0.9338 - auc: 0.9862 - val_loss: 0.6641 - val_accuracy: 0.6857 - val_auc: 0.7808 - lr: 0.0010
# Epoch 14/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1676 - accuracy: 0.9412 - auc: 0.9873 - val_loss: 0.6516 - val_accuracy: 0.6857 - val_auc: 0.7862 - lr: 0.0010
# Epoch 15/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1539 - accuracy: 0.9412 - auc: 0.9886 - val_loss: 0.6494 - val_accuracy: 0.6857 - val_auc: 0.7862 - lr: 1.0000e-04
# Epoch 16/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1520 - accuracy: 0.9485 - auc: 0.9891 - val_loss: 0.6482 - val_accuracy: 0.6857 - val_auc: 0.7862 - lr: 1.0000e-04
# Epoch 17/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1505 - accuracy: 0.9485 - auc: 0.9894 - val_loss: 0.6478 - val_accuracy: 0.6857 - val_auc: 0.7880 - lr: 1.0000e-04
# Epoch 18/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1484 - accuracy: 0.9485 - auc: 0.9907 - val_loss: 0.6492 - val_accuracy: 0.6857 - val_auc: 0.7862 - lr: 1.0000e-04
# Epoch 19/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1474 - accuracy: 0.9485 - auc: 0.9907 - val_loss: 0.6531 - val_accuracy: 0.6857 - val_auc: 0.7917 - lr: 1.0000e-04
# Epoch 20/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1459 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6565 - val_accuracy: 0.7143 - val_auc: 0.7917 - lr: 1.0000e-04
# Epoch 21/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1449 - accuracy: 0.9485 - auc: 0.9917 - val_loss: 0.6591 - val_accuracy: 0.7143 - val_auc: 0.7899 - lr: 1.0000e-04
# Epoch 22/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1438 - accuracy: 0.9485 - auc: 0.9916 - val_loss: 0.6604 - val_accuracy: 0.6571 - val_auc: 0.7880 - lr: 1.0000e-04
# Epoch 23/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1426 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6629 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-04
# Epoch 24/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1423 - accuracy: 0.9485 - auc: 0.9906 - val_loss: 0.6644 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-04
# Epoch 25/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1410 - accuracy: 0.9485 - auc: 0.9909 - val_loss: 0.6648 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 26/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1408 - accuracy: 0.9485 - auc: 0.9911 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 27/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1407 - accuracy: 0.9485 - auc: 0.9911 - val_loss: 0.6655 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 28/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1405 - accuracy: 0.9485 - auc: 0.9911 - val_loss: 0.6656 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 29/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1404 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6657 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 30/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1403 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6657 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 31/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1402 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6654 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 32/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1401 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 33/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1400 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6650 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 34/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1399 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-05
# Epoch 35/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 36/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 37/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 38/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 39/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 40/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 41/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6653 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 42/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 43/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1397 - accuracy: 0.9485 - auc: 0.9914 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 44/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-06
# Epoch 45/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-07
# Epoch 46/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-07
# Epoch 47/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-07
# Epoch 48/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-07
# Epoch 49/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-07
# Epoch 50/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1396 - accuracy: 0.9485 - auc: 0.9915 - val_loss: 0.6652 - val_accuracy: 0.6571 - val_auc: 0.7862 - lr: 1.0000e-07

# %%
plt.figure(figsize=(16,10))

plt.plot(range(epochs), history.history['loss'], label='Training Loss')
plt.plot(range(epochs), history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Time')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
results = model.evaluate(X_test, y_test)
acc = results[1]
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4874 - accuracy: 0.8784 - auc: 0.8947

# %%
y_true = np.array(y_test)

y_pred = np.squeeze(model.predict(X_test))
y_pred = np.array(y_pred >= 0.5, dtype=int)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e9decef4e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 4ms/step

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(4, 4))

sns.heatmap(cm, annot=True, fmt='g', vmin=0, cbar=False)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88        41
#            1       0.82      0.94      0.87        33
#
#     accuracy                           0.88        74
#    macro avg       0.88      0.88      0.88        74
# weighted avg       0.89      0.88      0.88        74

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 27)]              0
#
#  dense_15 (Dense)            (None, 256)               7168
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  dense_17 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 73217 (286.00 KB)
# Trainable params: 73217 (286.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save(f"/content/drive/My Drive/Colab Notebooks/Schizophrenia Classification Project/Models/simplenn_{scale_indicator[0]}{acc*100}%.keras")
# model.save(f"/content/drive/My Drive/Colab Notebooks/Schizophrenia Classification Project/Models/simplenn_with_features{int(acc*100)}%.keras")

# %%
results = model.evaluate(X_test, y_test)
type(results)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4874 - accuracy: 0.8784 - auc: 0.8947
# list
